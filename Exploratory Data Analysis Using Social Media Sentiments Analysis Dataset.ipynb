# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('sentimentdataset.csv')

# %%
data
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
data.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
# 5             5           5
# 6             6           6
# 7             7           7
# 8             8           8
# 9             9           9
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
# 5   Feeling grateful for the little things in lif...   Positive
# 6   Rainy days call for cozy blankets and hot coc...   Positive
# 7   The new movie release is a must-watch!       ...   Positive
# 8   Political discussions heating up on the timel...   Negative
# ...

# %%
data.tail(10)
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 722           723         727
# 723           724         728
# 724           725         729
# 725           726         730
# 726           727         731
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 722  Winning a friendly sports competition against ...    Happy
# 723  Receiving a heartfelt letter from a pen pal in...    Happy
# 724  Creating a beautiful mural with fellow art ent...    Happy
# 725  Participating in a school-wide art exhibition....    Happy
# 726  Achieving a personal best in a track and field...    Happy
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
data = data.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# %%
data
# Out:
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# 728  Attending a surprise birthday party organized ...       Happy
# 729  Successfully fundraising for a school charity ...       Happy
# 730  Participating in a multicultural festival, cel...       Happy
# 731  Organizing a virtual talent show during challe...       Happy
#
#                Timestamp                                   User     Platform  \
# 0    2023-01-15 12:30:00                          User123          Twitter
# ...

# %%
data.shape
# Out:
# (732, 13)

# %%
data.dtypes
# Out:
# Text          object
# Sentiment     object
# Timestamp     object
# User          object
# Platform      object
# Hashtags      object
# Retweets     float64
# Likes        float64
# Country       object
# Year           int64
# Month          int64
# Day            int64
# Hour           int64
# dtype: object

# %%
data.columns
# Out:
# Index(['Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour'],
#       dtype='object')

# %%
data.describe()
# Out:
#          Retweets       Likes         Year       Month         Day        Hour
# count  732.000000  732.000000   732.000000  732.000000  732.000000  732.000000
# mean    21.508197   42.901639  2020.471311    6.122951   15.497268   15.521858
# std      7.061286   14.089848     2.802285    3.411763    8.474553    4.113414
# min      5.000000   10.000000  2010.000000    1.000000    1.000000    0.000000
# 25%     17.750000   34.750000  2019.000000    3.000000    9.000000   13.000000
# 50%     22.000000   43.000000  2021.000000    6.000000   15.000000   16.000000
# 75%     25.000000   50.000000  2023.000000    9.000000   22.000000   19.000000
# max     40.000000   80.000000  2023.000000   12.000000   31.000000   23.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data['Likes'].dropna(), kde=True, bins=20, color='Red')
plt.title("Likes per country")
plt.xlabel('Likes')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.boxplot(x='Likes', data=data, color='lightgreen')
plt.title("Box Plot Of Likes")
plt.xlabel('Likes')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.DataFrame({
    'Platform': ['Android', 'iOS', 'Windows', 'Android', 'iOS', 'Windows', 'Android', 'Windows', 'iOS', 'Windows'],
    'Likes': [100, 150, 200, 250, 300, 150, 200, 250, 300, 350]
})

Likes_by_platform = data.groupby('Platform')['Likes'].sum().reset_index()

# Plotting the pie chart
plt.figure(figsize=(8, 8))  # Adjust the size of the figure
plt.pie(likes_by_platform['Likes'], labels=likes_by_platform['Platform'], autopct='%1.1f%%', colors=sns.color_palette('rainbow'))
plt.title('Total Likes by Platform')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

data = pd.DataFrame({
    'Platform': ['Android', 'iOS', 'Windows', 'Android', 'iOS', 'Windows', 'Android', 'Windows', 'iOS', 'Windows'],
    'Likes': [100, 150, 200, 250, 300, 150, 200, 250, 300, 350]
})
likes_by_platform = data.groupby('Platform')['Likes'].sum().reset_index()

colors = sns.color_palette('rainbow', len(likes_by_platform['Platform'].unique()))

color_map = dict(zip(likes_by_platform['Platform'].unique(), colors))

plt.figure(figsize=(10, 6)) 
bars = plt.bar(likes_by_platform['Platform'], likes_by_platform['Likes'], color=[color_map[platform] for platform in likes_by_platform['Platform']])

for bar, platform in zip(bars, likes_by_platform['Platform']):
    bar.set_color(color_map[platform])

plt.title('Total Likes by Platform')
plt.xlabel('Platform')
plt.ylabel('Total Likes')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
